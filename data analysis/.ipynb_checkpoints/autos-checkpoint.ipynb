# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
url = "imports-85.data"
df = pd.read_csv(url, header=None)
headers = ["symboling","normalizes-loses","make","fuel-type","aspiration","no-of-doors","body-style",
           "drive-wheels","engine-location","wheel-base","length","width","height","curb-weight","engine-type",
           "no-of-cylinders","engine-size","fuel-system","bore","stroke", "compression-ratio","horsepower",
           "peak-rpm","city-mpg","highway-mpg","price"]
df.columns = headers
df.head()
# Out:
#    symboling normalizes-loses         make fuel-type aspiration no-of-doors  \
# 0          3                ?  alfa-romero       gas        std         two
# 1          3                ?  alfa-romero       gas        std         two
# 2          1                ?  alfa-romero       gas        std         two
# 3          2              164         audi       gas        std        four
# 4          2              164         audi       gas        std        four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %%
df.dtypes
# Out:
# symboling              int64
# normalizes-loses      object
# make                  object
# fuel-type             object
# aspiration            object
# no-of-doors           object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# no-of-cylinders       object
# engine-size            int64
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower            object
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                 object
# dtype: object

# %%
df.describe(include="all")
# Out:
#          symboling normalizes-loses    make fuel-type aspiration no-of-doors  \
# count   205.000000              205     205       205        205         205
# unique         NaN               52      22         2          2           3
# top            NaN                ?  toyota       gas        std        four
# freq           NaN               41      32       185        168         114
# mean      0.834146              NaN     NaN       NaN        NaN         NaN
# std       1.245307              NaN     NaN       NaN        NaN         NaN
# min      -2.000000              NaN     NaN       NaN        NaN         NaN
# 25%       0.000000              NaN     NaN       NaN        NaN         NaN
# 50%       1.000000              NaN     NaN       NaN        NaN         NaN
# 75%       2.000000              NaN     NaN       NaN        NaN         NaN
# max       3.000000              NaN     NaN       NaN        NaN         NaN
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalizes-loses   205 non-null    object
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   no-of-doors        205 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  no-of-cylinders    205 non-null    object
# ...

# %%
# #data preprocessing or wranggling
# # Learning objectives
#     1. identify and handle msing values
#     2. data formatting
#     3. data normalization(centering and scaling)
#     4. data Bining
#     5. turning catagorical into numerical values

# %%
# df["symboling"] = df["symboling"]  + 1

# %%
df["symboling"]
# Out:
# 0      3
# 1      3
# 2      1
# 3      2
# 4      2
#       ..
# 200   -1
# 201   -1
# 202   -1
# 203   -1
# 204   -1
# Name: symboling, Length: 205, dtype: int64

# %%
# # How to deal with the missing values?
# #     Check the data collection source
    
# #     Drop the missing values
# #         1. drop the variable 
# #         2. or drop the data entry
    
# #     Replace the misiing values
#             1. replace it with an average
#             2. replace it by frequency
#             3. replace it based on other functions

# %%
# # HOw to drop misiing values

#         dataframes.dropna()
# axis =0 drops the entire row
# axis =1 drops the entire column


# df.dropna(subset=[('normalizes-loses')], axis=0, inplace=True)
df.isna()
# df.notna()

df['normalizes-loses'] = pd.to_numeric(df['normalizes-loses'], errors='coerce')
df['price'] = pd.to_numeric(df['price'], errors='coerce')

# df = df[~((df['normalizes-loses'] == '?' ))].astype(float)

df
# Out:
#      symboling  normalizes-loses         make fuel-type aspiration  \
# 0            3               NaN  alfa-romero       gas        std
# 1            3               NaN  alfa-romero       gas        std
# 2            1               NaN  alfa-romero       gas        std
# 3            2             164.0         audi       gas        std
# 4            2             164.0         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1              95.0        volvo       gas        std
# 201         -1              95.0        volvo       gas      turbo
# 202         -1              95.0        volvo       gas        std
# 203         -1              95.0        volvo    diesel      turbo
# 204         -1              95.0        volvo       gas      turbo
#
#     no-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0           two  convertible          rwd           front        88.6  ...
# ...

# %%
# how to replace missing values?

# df.replace(misiing_value, new_value)

mean = df["normalizes-loses"].mean()
print("The mean of normalizes-loses is:", mean)
df["normalizes-loses"]= df["normalizes-loses"].replace(np.nan, mean)
df
# Out:
# The mean of normalizes-loses is: 122.0
#      symboling  normalizes-loses         make fuel-type aspiration  \
# 0            3             122.0  alfa-romero       gas        std
# 1            3             122.0  alfa-romero       gas        std
# 2            1             122.0  alfa-romero       gas        std
# 3            2             164.0         audi       gas        std
# 4            2             164.0         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1              95.0        volvo       gas        std
# 201         -1              95.0        volvo       gas      turbo
# 202         -1              95.0        volvo       gas        std
# 203         -1              95.0        volvo    diesel      turbo
# 204         -1              95.0        volvo       gas      turbo
#
#     no-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# ...

# %%
# # data formatting
# #     bringing data into a commom standard of expression allows users to make mesningful comparisons
#         For consistency and understanable


#converting "mpg" to L/100Km

df["city-mpg"] = 235/df["city-mpg"]

df.rename(columns={"city-mpg": "city-L/100km"}, inplace=True)

# %%
df.dtypes
# Out:
# symboling              int64
# normalizes-loses     float64
# make                  object
# fuel-type             object
# aspiration            object
# no-of-doors           object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# no-of-cylinders       object
# engine-size            int64
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower            object
# peak-rpm              object
# city-L/100km         float64
# highway-mpg            int64
# price                float64
# dtype: object

# %%
mean = df["price"].mean()
print("The mean of prices is:", mean)
df["price"].replace(np.nan, mean)


df["price"] = df["price"].astype("int64")
df
# Out:
# The mean of prices is: 13207.129353233831
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-90bebdb0938f> in <module>
#       4
#       5
# ----> 6 df["price"] = df["price"].astype("int64")
#       7 df
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5696         else:
#    5697             # else, only a single dtype is given
# -> 5698             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors)
#    5699             return self._constructor(new_data).__finalize__(self)
#    5700
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     580
#     581     def astype(self, dtype, copy: bool = False, errors: str = "raise"):
# --> 582         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     583
# ...

# %%
df["length"]
# Out:
# 0      168.8
# 1      168.8
# 2      171.2
# 3      176.6
# 4      176.6
#        ...
# 200    188.8
# 201    188.8
# 202    188.8
# 203    188.8
# 204    188.8
# Name: length, Length: 205, dtype: float64

# %%
# # Data Normalization

# Uniform the featues values with different range

# 1. simple feature scaling 
#             x-new = x-old / x-max

# 2. min-MAx
#             x-new = (x-old - x-min) / (x-max -x-min)

# 3. Z-score
#             x-new = (x-old - mean) / S.D
#             ranges from -3 to 3 id if data normally distributed

# %%
# Applying MIN_MAX 
df["length"] = (df["length"] - df["length"].min())/(df["length"].max()-df["length"].min())
df["length"]
# Out:
# 0      0.413433
# 1      0.413433
# 2      0.449254
# 3      0.529851
# 4      0.529851
#          ...
# 200    0.711940
# 201    0.711940
# 202    0.711940
# 203    0.711940
# 204    0.711940
# Name: length, Length: 205, dtype: float64

# %%
# data bining

bins = np.linspace(min(df["price"]),max(df["price"]),4)
group_names = ["Low", "Medium", "High"]
df["price-binned"] = pd.cut(df["price"], bins, labels=group_names, include_lowest=True)
df
# Out:
#      symboling  normalizes-loses         make fuel-type aspiration  \
# 0            3             122.0  alfa-romero       gas        std
# 1            3             122.0  alfa-romero       gas        std
# 2            1             122.0  alfa-romero       gas        std
# 3            2             164.0         audi       gas        std
# 4            2             164.0         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1              95.0        volvo       gas        std
# 201         -1              95.0        volvo       gas      turbo
# 202         -1              95.0        volvo       gas        std
# 203         -1              95.0        volvo    diesel      turbo
# 204         -1              95.0        volvo       gas      turbo
#
#     no-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0           two  convertible          rwd           front        88.6  ...
# ...

# %%
df.describe()
# Out:
#         symboling  normalizes-loses  wheel-base      length       width  \
# count  205.000000        205.000000  205.000000  205.000000  205.000000
# mean     0.834146        122.000000   98.756585    0.491780   65.907805
# std      1.245307         31.681008    6.021776    0.184139    2.145204
# min     -2.000000         65.000000   86.600000    0.000000   60.300000
# 25%      0.000000        101.000000   94.500000    0.376119   64.100000
# 50%      1.000000        122.000000   97.000000    0.479104   65.500000
# 75%      2.000000        137.000000  102.400000    0.626866   66.900000
# max      3.000000        256.000000  120.900000    1.000000   72.300000
#
#            height  curb-weight  engine-size  compression-ratio  city-L/100km  \
# count  205.000000   205.000000   205.000000         205.000000    205.000000
# mean    53.724878  2555.565854   126.907317          10.142537      9.949525
# std      2.443522   520.680204    41.642693           3.972040      2.573104
# ...
